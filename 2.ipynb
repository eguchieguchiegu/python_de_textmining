# %% [markdown]
# <a href="https://colab.research.google.com/github/eguchieguchiegu/python_de_textmining/blob/main/2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures

from google.colab import drive
drive.mount('/content/drive', force_remount = True)

filename = "/content/drive/MyDrive/shizengengo/data2-1.csv"

import pandas as pd
df = pd.read_csv(filename, encoding = "utf-8-sig")

x = (df['x']).values.reshape(-1, 1)
y = (df['y']).values.reshape(-1, 1)
# Out:
# Mounted at /content/drive

# %%
model = LinearRegression()
model.fit(x, y)

y_pred = model.predict(x)

rmse = np.sqrt(mean_squared_error(y, y_pred))
print("RMSE:", rmse)

plt.scatter(x, y)
plt.plot(x, y_pred, color = 'red')
plt.show()
# Out:
# RMSE: 6.127592143619536

# %%
polynomial_features = PolynomialFeatures(degree = 3)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)

y_pred = model.predict(x_poly)

rmse = np.sqrt(mean_squared_error(y, y_pred))
print("RMSE:", rmse)

plt.scatter(x, y)
plt.plot(x, y_pred, color = 'r')
plt.show()
# Out:
# RMSE: 5.960099093015269
